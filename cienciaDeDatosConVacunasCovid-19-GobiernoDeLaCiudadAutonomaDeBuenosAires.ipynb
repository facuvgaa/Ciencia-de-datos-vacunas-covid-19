# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as pl 


data1 = pd.read_csv(r"C:\Users\facun\Downloads\vacunas.csv")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15263 entries, 0 to 15262
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   FECHA_ADMINISTRACION  15263 non-null  object
#  1   GRUPO_ETARIO          15263 non-null  object
#  2   GENERO                15263 non-null  object
#  3   VACUNA                15263 non-null  object
#  4   TIPO_EFECTOR          15263 non-null  object
#  5   DOSIS_1               15263 non-null  int64
#  6   DOSIS_2               15263 non-null  int64
#  7   ID_CARGA              0 non-null      float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 954.1+ KB

# %%
data1.groupby("GENERO")["DOSIS_1"].size().plot.bar()
# Out:
# <AxesSubplot:xlabel='GENERO'>

# %%
data1.groupby("GENERO")["DOSIS_2"].size().plot.bar()
# Out:
# <AxesSubplot:xlabel='GENERO'>

# %%
data1.groupby("DOSIS_1")["DOSIS_2"].sum().plot.pie(title ="proporcion de dosis 1 y dosis 2  ")
# Out:
# <AxesSubplot:title={'center':'proporcion de dosis 1 y dosis 2  '}, ylabel='DOSIS_2'>

# %%
data1.groupby("VACUNA").size().plot.pie(title = "proporcion de marca de vacunas ")
# Out:
# <AxesSubplot:title={'center':'proporcion de marca de vacunas '}, ylabel='None'>

# %%
data1.groupby("DOSIS_1").size()
# Out:
# DOSIS_1
# 0        3513
# 1        1927
# 2         970
# 3         657
# 4         490
#          ...
# 13548       1
# 14286       1
# 14471       1
# 14614       1
# 16481       1
# Length: 1141, dtype: int64

# %%
data1.groupby("VACUNA").size()
# Out:
# VACUNA
# AstraZeneca                                                            4464
# Moderna                                                                 561
# Sinopharm                                                              3310
# Sputnik                                                                6643
# vacuna Coronavirus (CANSINO), vial x 1 dosis                            206
# vacuna Coronavirus (PFIZER) 1ra - 2da dosis, vial x 6 dosis (0.3ml)      79
# dtype: int64

# %%
data1
# Out:
# <AxesSubplot:xlabel='GENERO'>
